# %% [markdown]
# # ART tutorial 1: Improve production for synthetic data

# %% [markdown]
# This notebook demostrates how to use the [Automated Recommendation Tool](https://www.nature.com/articles/s41467-020-18008-4) (ART) to guide a simulated bioengineering process, where the production is given by an 'easy' function.

# %% [markdown]
# Tested using **ART Prod** kernel on [skynet.ese.lbl.gov](https://skynet.ese.lbl.gov)

# %% [markdown]
# ## Setup

# %% [markdown]
# The first step to run this notebook  is to make sure the `ART` library is installed.
#
# If it is not, clone the corresponding git repository (or pull the latest version) to install it:
#
# `git clone https://github.com/JBEI/AutomatedRecommendationTool.git`
#
# Information about licensing ART is available at https://github.com/JBEI/ART.

# %% [markdown]
# Next, we need to add the library to the path, and import its functions:

# %%
import os
import sys
from pathlib import Path
sys.path.append('.')   # Add local directory to access some of the functions
sys.path.append('../') # Make sure this is the location for the ART library

import warning_utils
warning_utils.filter_end_user_warnings()

import pandas as pd
import numpy as np
import auxiliary_functions
import copy
from IPython.display import Image  # Used to display images
import cloudpickle

# %%
from art.core import RecommendationEngine
import art.utility as utils

# %% [markdown]
# ## Deciding the input and response

# %% [markdown]
# ART (and most of [machine learning](https://www.sciencedirect.com/science/article/pii/S109671762030166X)) works by learning the connection between a set of *inputs* (e.g. concentration for proteins in a pathway) and a corresponding *response* (e.g. production of biofuel). We will use a training set of known inputs and responses to derive a predictive model able to predict the response for new input, and then use that predictive models to find inputs that are predicted to improve our response:

# %%
Image("ARToverview.png")

# %% [markdown]
# The predictions are probabilistic: i.e. instead of predicting that the protein concentrations $p_1 = 0.5, p_2 = 0.2, p_3 = 0.7$ will produce a production of 15 mg/L, the prediction is given in terms of a probability distribution. This probability distribution approach predicts that for $p_1 = 0.5, p_2 = 0.2, p_3 = 0.7$, there is e.g. a 10% chance of producing at most 10 mg/L, a 20% chance of producing at most 15 mg/L, etc. Hence this approach *quantifies uncertainty* for the prediction, which is a very useful characteristic when dealing with the small data sets characteristic of the field of synthetic biology.

# %% [markdown]
# For this tutorial, and for the sake of the example, our **input** will be composed of the concentrations for two proteins in the [mevalonate pathway](https://www.sciencedirect.com/science/article/pii/S109671761400161X?casa_token=CgEdQ91wK-sAAAAA:xWMpxuffL5Ukj7tyacW08VmwdR5jz1u8IjeXxJWb_FNMfn17yN_4XrVKgN2_Xql4Swjg8tIFf9bH) (e.g. atoB and HMGS) and the **response** will be isoprenol production. We will try to increase isoprenol production.
#
# However, everything we do below will be usable for other pathway, final metabolite, number of proteins, transcripts or promoter combinations. This is a general procedure.

# %% [markdown]
# ## Defining the true response function

# %% [markdown]
# Rather than using experimental data for this tutorial, we will simulate it through an easy to learn function, of dimension 2 (the number of proteins in the input):

# %%
dimension = 2     # number of dimensions
lb, ub = 0., 10.  # lower and upper bounds for inputs (protein levels)

# %%
def true_function_easy(p, dimension):
    term1 = 0.
    term2 = 0.
    for i in range(dimension):
        term1 += (p[i] - 8)**2
        term2 += (p[i] - 3)**2

    return 25 - (1/dimension * term1 + np.exp(-term2))

# %% [markdown]
# This is a function that links the response $r$ (isoprenol production) to the concentration of proteins $p_1$ (atoB) and $p_2$ (HMGS) as follows:
#
# $r = 25 - \left(\frac{1}{2}\left((p_1-8)^2+(p_2-8)^2\right) + e^{-\left((p_1-3)^2+(p_2-3)^2\right)}\right)$
#
# and looks like this:

# %%
auxiliary_functions.plot_function(true_function_easy, [lb,ub], dimension)

# %% [markdown]
# This functon is just a convenient example for this tutorial. We could have used a more realistic way to determine the relation between the isoprenol production (r) and the proteins ($p_1$,$p_2$) by using the [Omics Mock Generator](https://www.frontiersin.org/articles/10.3389/fbioe.2021.612893/full) (OMG) library, for example. However, for the purpose of this tutorial, this simplification suffices. The important point is that it does not matter whether the relation between response and input is given by synthetic data or real experimental data: the following steps are the same.

# %% [markdown]
# ## ART input

# %% [markdown]
# ### Defining the user parameters for running ART

# %% [markdown]
# It is useful to collect in a single dictionary all the parameters that we will use as inputs for ART to learn the function we defined above.
#
# For example, the first parameter is the dimensionality of the input (in our case, we have two proteins, $p_1$ and $p_2$, so the dimensionality is 2:

# %%
user_params = {'dim': dimension}

# %% [markdown]
# Then we need to tell ART which are the input ($p_1$ and $p_2$) and response ($r$) variables:

# %%
input_var = ['p_' + str(i) for i in range(1, user_params['dim'] + 1)]
response_var = ['r']

# %% [markdown]
# And then decide how many [instances](https://www.sciencedirect.com/science/article/pii/S109671762030166X#fig3) we will use for the initial DBTL cycle:

# %%
user_params['n_instances_cycle1'] = 7

# %% [markdown]
# We also need to define the number of [recommendations](https://www.nature.com/articles/s41467-020-18008-4/figures/1) for new inputs to be generated at each DBTL cycle:

# %%
user_params['num_recommendations'] = 5

# %% [markdown]
# as well as how many Design-Build-Test-Learn ([DBTL](https://www.frontiersin.org/files/Articles/160125/fbioe-03-00135-HTML/image_m/fbioe-03-00135-g001.jpg)) cycles we will do:

# %%
user_params['n_cycles'] = 4

# %% [markdown]
# We also need to tell ART what is our objective (in this case to maximize the response), and what we consider a success (in this case a 20% improvement over the best in the training data set, i.e., the threshold of 0.2):

# %%
user_params['objective'] = 'maximize'
user_params['threshold'] = 0.2

# %% [markdown]
# Also, ART needs an output directory for storing the results generated, and a random number generator seed to enable repeatability of the run (although the process is random, processes with the same seed should produce the same results):

# %%
user_params['output_dir'] = '../results/tutorial'
os.makedirs(user_params['output_dir'], exist_ok=True)

user_params['seed'] = 30

# %% [markdown]
# Finally, we need to define the exploitation-exploration parameter `alpha` ($\alpha$). This parameter determines whether we want to create recommendations to *explore* the parts of the phase space where our model is less precise ($\alpha \sim 1$), or recommend new points that will *exploit* our model to obtain the highest production ($\alpha \sim 0$):

# %%
user_params['alpha_cycle2'] = 0.9
user_params['alpha_cycle3'] = 0.5
user_params['alpha_cycle4'] = None

# %% [markdown]
# You can find more details regarding $\alpha$ in equation (5) from the [ART paper](https://www.nature.com/articles/s41467-020-18008-4).

# %% [markdown]
# ### Create file with bounds for input variables

# %% [markdown]
# Here we define the constraints on the input variables. For example, we limit ourselves only to positive values with an upper bound.

# %%
dim = user_params['dim']

bounds = pd.DataFrame(columns=['Variable', 'Min', 'Max'])
bounds['Variable'] = ['p_' + str(i) for i in range(1, dim + 1)]
bounds['Min'] = lb*np.ones(dim)
bounds['Max'] = ub*np.ones(dim)
bounds = bounds.set_index('Variable')

display(bounds)
bounds_file = f"{user_params['output_dir']}/sim_data_bounds_FE.csv"
bounds.to_csv(path_or_buf=bounds_file)
# Out:
#           Min   Max
# Variable
# p_1       0.0  10.0
# p_2       0.0  10.0

# %% [markdown]
# ## DBTL cycles

# %% [markdown]
# We are now ready to start the Design-Build-Test-Learn cycles that will lead us to an increased production of isoprenol.

# %%
Image("DBTL.png")

# %% [markdown]
# ### DBTL cycle 1

# %%
cycle = 1

# %% [markdown]
# #### Define input parameters

# %% [markdown]
# For the first cycle, we have no previously gathered information to make recommendations from, so we will create a set of recommended inputs such that they cover as much phase space as possible. This is achieved through the Latin Hypercube method ([McKay et al., 1979](https://amstat.tandfonline.com/doi/abs/10.1080/00401706.2000.10485979?casa_token=t3rYToRQxNUAAAAA%3AedYxZ4BsQrB2BDGIEw1ALAKNwgZIV-GOjEURzCT9rv1kdP_chO8DzEF4qS5P7_w89_SotCL_BbBsHnI&#.YAeui-lKii4)), which is included in ART and can be summoned setting input parameter `initial_cycle` to `True`. The rest of the parameters are explained above:

# %%
art_params = {
    'bounds': utils.read_table(bounds_file),
    'input_vars': input_var,
    'num_recommendations': user_params['n_instances_cycle1'],
    'initial_cycle': True,                                    # Set this to True for initial designs recommendations
    'seed': user_params['seed'],
    'output_dir': user_params['output_dir'],
    'result_suffix': "_C1",
}

# %% [markdown]
# #### Run ART

# %% [markdown]
# The next step is to run arts with the parameters we included in `art_params`:

# %%
art = RecommendationEngine(**art_params)

# %% [markdown]
# The recommendations can be found in the `art` structure:

# %%
art.recommendations
# Out:
#         p_1       p_2
# 0  7.337478  0.543926
# 1  2.375783  4.621511
# 2  6.550992  9.666936
# 3  4.232297  7.920195
# 4  0.920205  6.295272
# 5  5.702501  1.662358
# 6  9.311680  3.352374

# %%
x = [a for a in art.recommendations['p_1']]
y = [a for a in art.recommendations['p_2']]

# %% [markdown]
# As you can see the values are chosen to be representative of the variability of the input space:

# %%
auxiliary_functions.plot_function(true_function_easy, [lb,ub], dimension, points=[x,y])

# %% [markdown]
# #### Save results as training data for next cycle

# %% [markdown]
# We now save this initial recommendations from the Latin Hypercube method in EDD-style files, to be used in the next cycle:

# %%
P = art.recommendations.values
r = true_function_easy(P.T, dim).reshape(-1, 1)
training_data_file = f'{art.output_dir}/sim_data_FE_cycle{str(cycle + 1)}.csv'
utils.save_edd_csv(P, r, art.input_vars, training_data_file, response_vars=response_var[0])

# %%
r_cycle1 = r
max(r_cycle1)[0]
# Out:
# 22.56085004489315

# %% [markdown]
# ### DBTL cycle 2

# %%
cycle += 1

# %% [markdown]
# #### Define input parameters

# %% [markdown]
# We change the parameters dictionary to reflect the new parameters for this cycle. The parameters include the objective, the threshold and the exploitation-exploration parameter $\alpha$:

# %%
art_params = {
    'bounds': utils.read_table(bounds_file),
    'input_vars': input_var,
    'response_vars': response_var,
    'objective': user_params['objective'],
    'threshold': user_params['threshold'],
    'alpha': user_params['alpha_cycle2'],
    'num_recommendations': user_params['num_recommendations'],
    'max_mcmc_cores': 2,
    'seed': user_params['seed'],
    'output_dir': user_params['output_dir'],
    'result_suffix':'_C2',
}

# %% [markdown]
# Import training data file from previous DBTL cycle into a pandas dataframe:

# %%
df = utils.load_study(data_file=training_data_file)

# %% [markdown]
# #### Run ART

# %% [markdown]
# We know run ART to learn from those initial 7 instances, and the result are three graphs:

# %%
run_art = True

# %%
# %%time
if run_art:
    art = RecommendationEngine(df=df, **art_params)
else:
    cloudpickle_file = Path(art_params['output_dir'], f'art_C2.cpkl')
    with open(cloudpickle_file, 'rb') as output:
        art = cloudpickle.load(output)
# Out:
# ART identified 7 unique designs in the training data.
# Correctly communicating your designs is critical to building ART's model and to cross-validation.  We strongly suggest verifying ART's interpretation of your designs by inspecting the preprocessed DataFrame.  For example, if your ART instance is named `engine`, run `engine.df["Design"]`.  See Data Preparation docs for a description of how ART infers design information. https://lbl-biosci.gitlab.io/ese/art/Data_Preparation/#labeling-lines-designs-replicates-oh-my
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [sigma, omegas]
# Sampling 2 chains for 1_000 tune and 10_000 draw iterations (2_000 + 20_000 draws total) took 14 seconds.
# We recommend running at least 4 chains for robust computation of convergence diagnostics
# Sampling: [y]
# Sampling: [y]
# /usr/local/art/.venv/lib/python3.12/site-packages/seaborn/axisgrid.py:123: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/art/.venv/lib/python3.12/site-packages/seaborn/axisgrid.py:123: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/art/.venv/lib/python3.12/site-packages/seaborn/axisgrid.py:123: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/art/.venv/lib/python3.12/site-packages/seaborn/axisgrid.py:123: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/art/.venv/lib/python3.12/site-packages/seaborn/axisgrid.py:123: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# CPU times: user 2min 8s, sys: 2.4 s, total: 2min 10s
# Wall time: 16min 46s

# %% [markdown]
# The first graph involves a comparison between observed data and predictions. In this case, the predictions are good ($R^2 = 0.88$), despite ART not having too many instances to learn from.
#
# The second graph involves the probability distribution for the response (isoprenol production in this case) for each of the recommendations (5 in this case, as specified above under `num_recommendations`) provided by ART. The continous vertical line is the mean for each distribution, and the discontinous line is the best production level in the training data set.
#
# The third graph indicates the probability of achieving success as a function of strains tested. In this case, testing the 5 recommendations provided has \~70\% of achieving success

# %% [markdown]
# This is the maximum response among the seven instances:

# %%
max(art.y)[0]
# Out:
# 22.56085004489315

# %% [markdown]
# This the threshold for success (20% as discussed before):

# %%
art.threshold
# Out:
# 0.2

# %% [markdown]
# And this is the production level that ART would consider a success for the purposes of the third graph:

# %%
max(art.y)[0] * (1+art.threshold)
# Out:
# 27.07302005387178

# %% [markdown]
# #### Save training data for next cycle

# %% [markdown]
# We now simulate true values for the response variable for the ART recommendations using `true_function`, and save data in an EDD-style .csv file:

# %%
file_name = f'{art.output_dir}/sim_data_FE_cycle{str(cycle + 1)}.csv'
r_cycle2 = auxiliary_functions.simulate_recommendations_responses(art, true_function_easy, user_params['dim'], file_name)

# %% [markdown]
# The maximum value obtained by the recommendations is then:

# %%
max(r_cycle2)[0]
# Out:
# 24.51074244901484

# %% [markdown]
# which is pretty much the maximum (25).

# %% [markdown]
# ### DBTL cycle 3

# %%
cycle += 1

# %% [markdown]
# #### Define input parameters

# %% [markdown]
# Let's configure ART for the next cycle (no changes from previous cycle except new value of $\alpha$):

# %%
art_params['alpha'] = user_params['alpha_cycle3']
art_params["result_suffix"] = "_C3"

# %% [markdown]
# Import training data file into a pandas dataframe:

# %%
df = utils.load_study(data_file=f'{art.output_dir}/sim_data_FE_cycle{str(cycle)}.csv')

# %% [markdown]
# #### Run ART

# %% [markdown]
# Let's train ART with the response values associated with the recommended protein values obtained from cycle 2:

# %%
run_art = True

# %%
# %%time
if run_art:
    art = RecommendationEngine(df=df, **art_params)
else:
    cloudpickle_file = Path(art_params['output_dir'], f'art_C3.cpkl')
    with open(cloudpickle_file, 'rb') as file:
        art = cloudpickle.load(file)
# Out:
# ART identified 12 unique designs in the training data.
# Correctly communicating your designs is critical to building ART's model and to cross-validation.  We strongly suggest verifying ART's interpretation of your designs by inspecting the preprocessed DataFrame.  For example, if your ART instance is named `engine`, run `engine.df["Design"]`.  See Data Preparation docs for a description of how ART infers design information. https://lbl-biosci.gitlab.io/ese/art/Data_Preparation/#labeling-lines-designs-replicates-oh-my
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# /usr/local/art/.venv/lib/python3.12/site-packages/sklearn/gaussian_process/_gpr.py:660: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL: .
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
# /usr/local/art/.venv/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__k1__constant_value is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/art/.venv/lib/python3.12/site-packages/sklearn/gaussian_process/_gpr.py:660: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL: .
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
# /usr/local/art/.venv/lib/python3.12/site-packages/sklearn/gaussian_process/_gpr.py:660: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL: .
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
# /usr/local/art/.venv/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__k1__constant_value is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/art/.venv/lib/python3.12/site-packages/sklearn/gaussian_process/_gpr.py:660: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL: .
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
# /usr/local/art/.venv/lib/python3.12/site-packages/sklearn/gaussian_process/_gpr.py:660: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL: .
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
# /usr/local/art/.venv/lib/python3.12/site-packages/sklearn/gaussian_process/_gpr.py:660: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL: .
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
# /usr/local/art/.venv/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__k1__constant_value is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/art/.venv/lib/python3.12/site-packages/sklearn/gaussian_process/_gpr.py:660: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL: .
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
# /usr/local/art/.venv/lib/python3.12/site-packages/sklearn/gaussian_process/_gpr.py:660: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL: .
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
# /usr/local/art/.venv/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__k1__constant_value is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/art/.venv/lib/python3.12/site-packages/sklearn/gaussian_process/_gpr.py:660: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL: .
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
# /usr/local/art/.venv/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__k1__constant_value is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/art/.venv/lib/python3.12/site-packages/sklearn/gaussian_process/_gpr.py:660: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL: .
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [sigma, omegas]
# Sampling 2 chains for 1_000 tune and 10_000 draw iterations (2_000 + 20_000 draws total) took 29 seconds.
# There were 531 divergences after tuning. Increase `target_accept` or reparameterize.
# We recommend running at least 4 chains for robust computation of convergence diagnostics
# Sampling: [y]
# Sampling: [y]
# /usr/local/art/.venv/lib/python3.12/site-packages/seaborn/axisgrid.py:123: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/art/.venv/lib/python3.12/site-packages/seaborn/axisgrid.py:123: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/art/.venv/lib/python3.12/site-packages/seaborn/axisgrid.py:123: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/art/.venv/lib/python3.12/site-packages/seaborn/axisgrid.py:123: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/art/.venv/lib/python3.12/site-packages/seaborn/axisgrid.py:123: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# CPU times: user 1min 49s, sys: 1.31 s, total: 1min 50s
# Wall time: 14min 2s

# %% [markdown]
# In this third cycle (second with simulated experimental results), the predictions are perfect $(R^2=1.0)$, indicating that ART has learnt to predict the response for all training inputs.
# The new recommendations cannot really improve since the previous cycle recommendations already reached the maximum:

# %%
max(art.y)[0]
# Out:
# 24.51074244901484

# %% [markdown]
# And the probability that at least one strain exhibits production 20% over the maximum is zero since ART has now accuretaly learnt the production distribution, and the maximum is already around 25.
#
# Hence the success probablity graph is at zero.

# %% [markdown]
# ## DBTL cycles for different number of starting instances

# %% [markdown]
# Let's see now what happens if we have different number of initial recommendations.

# %% [markdown]
# ### DBTL Cycle 1

# %%
cycle = 1

# %% [markdown]
# #### Define input parameters

# %% [markdown]
# First, let's create different sets of user parameters that differ only in the numbes of instances for cycle 1:

# %%
user_params_A  = copy.deepcopy(user_params) ; user_params_A['n_instances_cycle1'] = 7
user_params_B  = copy.deepcopy(user_params) ; user_params_B['n_instances_cycle1'] = 15
user_params_C  = copy.deepcopy(user_params) ; user_params_C['n_instances_cycle1'] = 30

# %%
art_params_A = {
    'bounds': utils.read_table(bounds_file),
    'input_vars': input_var,
    'num_recommendations': user_params_A['n_instances_cycle1'],
    'initial_cycle': True,                                    # Set this to True for initial designs recommendations
    'seed': user_params_A['seed'],
    'output_dir': user_params_A['output_dir']
}

# %%
art_params_B = {
    'bounds': utils.read_table(bounds_file),
    'input_vars': input_var,
    'num_recommendations': user_params_B['n_instances_cycle1'],
    'initial_cycle': True,                                    # Set this to True for initial designs recommendations
    'seed': user_params_B['seed'],
    'output_dir': user_params_B['output_dir']
}

# %%
art_params_C = {
    'bounds': utils.read_table(bounds_file),
    'input_vars': input_var,
    'num_recommendations': user_params_C['n_instances_cycle1'],
    'initial_cycle': True,                                    # Set this to True for initial designs recommendations
    'seed': user_params_C['seed'],
    'output_dir': user_params_C['output_dir']
}

# %% [markdown]
# #### Run ART

# %% [markdown]
# And now we can run each of them separately:

# %%
art_A = RecommendationEngine(**art_params_A)
art_B = RecommendationEngine(**art_params_B)
art_C = RecommendationEngine(**art_params_C)

# %% [markdown]
# #### Save results as training data for next cycle

# %% [markdown]
# And here are the initial recommendations:

# %%
P_A = art_A.recommendations.values
r_A = true_function_easy(P_A.T, dim).reshape(-1, 1)
training_data_file_A = f'{art.output_dir}/sim_data_FE_cycle{str(cycle + 1)}_A.csv'     #Substitute file
utils.save_edd_csv(P_A, r_A, art_A.input_vars, training_data_file_A, response_vars=response_var[0])

# %%
P_B = art_B.recommendations.values
r_B = true_function_easy(P_B.T, dim).reshape(-1, 1)
training_data_file_B = f'{art.output_dir}/sim_data_FE_cycle{str(cycle + 1)}_B.csv'     #Substitute file
utils.save_edd_csv(P_B, r_B, art_B.input_vars, training_data_file_B, response_vars=response_var[0])

# %%
P_C = art_C.recommendations.values
r_C = true_function_easy(P_C.T, dim).reshape(-1, 1)
training_data_file_C = f'{art.output_dir}/sim_data_FE_cycle{str(cycle + 1)}_C.csv'     #Substitute file
utils.save_edd_csv(P_C, r_C, art_C.input_vars, training_data_file_C, response_vars=response_var[0])

# %% [markdown]
# ### DBTL Cycle 2

# %%
cycle += 1

# %% [markdown]
# #### Define input parameters

# %%
art_params = {
    'bounds': utils.read_table(bounds_file),
    'input_vars': input_var,
    'response_vars': response_var,
    'objective': user_params['objective'],
    'threshold': user_params['threshold'],
    'alpha': user_params['alpha_cycle2'],
    'num_recommendations': user_params['num_recommendations'],
    'max_mcmc_cores': 2,
    'seed': user_params['seed'],
    'output_dir': user_params['output_dir']
}

# %%
df_A = utils.load_study(data_file=training_data_file_A)
df_B = utils.load_study(data_file=training_data_file_B)
df_C = utils.load_study(data_file=training_data_file_C)

# %% [markdown]
# #### Run ART

# %%
# %%time
art_A = RecommendationEngine(df=df_A, **art_params)
# Out:
# ART identified 7 unique designs in the training data.
# Correctly communicating your designs is critical to building ART's model and to cross-validation.  We strongly suggest verifying ART's interpretation of your designs by inspecting the preprocessed DataFrame.  For example, if your ART instance is named `engine`, run `engine.df["Design"]`.  See Data Preparation docs for a description of how ART infers design information. https://lbl-biosci.gitlab.io/ese/art/Data_Preparation/#labeling-lines-designs-replicates-oh-my
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [sigma, omegas]
# Sampling 2 chains for 1_000 tune and 10_000 draw iterations (2_000 + 20_000 draws total) took 10 seconds.
# We recommend running at least 4 chains for robust computation of convergence diagnostics
# Sampling: [y]
# Sampling: [y]
# /usr/local/art/.venv/lib/python3.12/site-packages/seaborn/axisgrid.py:123: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/art/.venv/lib/python3.12/site-packages/seaborn/axisgrid.py:123: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/art/.venv/lib/python3.12/site-packages/seaborn/axisgrid.py:123: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/art/.venv/lib/python3.12/site-packages/seaborn/axisgrid.py:123: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/art/.venv/lib/python3.12/site-packages/seaborn/axisgrid.py:123: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# CPU times: user 1min 41s, sys: 1.13 s, total: 1min 42s
# Wall time: 14min 26s

# %%
# %%time
art_B = RecommendationEngine(df=df_B, **art_params)
# Out:
# ART identified 15 unique designs in the training data.
# Correctly communicating your designs is critical to building ART's model and to cross-validation.  We strongly suggest verifying ART's interpretation of your designs by inspecting the preprocessed DataFrame.  For example, if your ART instance is named `engine`, run `engine.df["Design"]`.  See Data Preparation docs for a description of how ART infers design information. https://lbl-biosci.gitlab.io/ese/art/Data_Preparation/#labeling-lines-designs-replicates-oh-my
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [sigma, omegas]
# Sampling 2 chains for 1_000 tune and 10_000 draw iterations (2_000 + 20_000 draws total) took 24 seconds.
# There were 301 divergences after tuning. Increase `target_accept` or reparameterize.
# We recommend running at least 4 chains for robust computation of convergence diagnostics
# Sampling: [y]
# Sampling: [y]
# /usr/local/art/.venv/lib/python3.12/site-packages/seaborn/axisgrid.py:123: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/art/.venv/lib/python3.12/site-packages/seaborn/axisgrid.py:123: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/art/.venv/lib/python3.12/site-packages/seaborn/axisgrid.py:123: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/art/.venv/lib/python3.12/site-packages/seaborn/axisgrid.py:123: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/art/.venv/lib/python3.12/site-packages/seaborn/axisgrid.py:123: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# CPU times: user 1min 40s, sys: 1.26 s, total: 1min 42s
# Wall time: 9min 14s

# %%
# %%time
art_C = RecommendationEngine(df=df_C, **art_params)
# Out:
# ART identified 30 unique designs in the training data.
# Correctly communicating your designs is critical to building ART's model and to cross-validation.  We strongly suggest verifying ART's interpretation of your designs by inspecting the preprocessed DataFrame.  For example, if your ART instance is named `engine`, run `engine.df["Design"]`.  See Data Preparation docs for a description of how ART infers design information. https://lbl-biosci.gitlab.io/ese/art/Data_Preparation/#labeling-lines-designs-replicates-oh-my
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# /usr/local/art/.venv/lib/python3.12/site-packages/sklearn/gaussian_process/_gpr.py:660: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL: .
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [sigma, omegas]
# Sampling 2 chains for 1_000 tune and 10_000 draw iterations (2_000 + 20_000 draws total) took 28 seconds.
# There were 555 divergences after tuning. Increase `target_accept` or reparameterize.
# We recommend running at least 4 chains for robust computation of convergence diagnostics
# Sampling: [y]
# Sampling: [y]
# /usr/local/art/.venv/lib/python3.12/site-packages/seaborn/axisgrid.py:123: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/art/.venv/lib/python3.12/site-packages/seaborn/axisgrid.py:123: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/art/.venv/lib/python3.12/site-packages/seaborn/axisgrid.py:123: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/art/.venv/lib/python3.12/site-packages/seaborn/axisgrid.py:123: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/art/.venv/lib/python3.12/site-packages/seaborn/axisgrid.py:123: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# CPU times: user 2min 2s, sys: 1.4 s, total: 2min 4s
# Wall time: 9min 27s

# %% [markdown]
# As you can see the difference is significant: the larger the number of initial training instances the better the predictions.
